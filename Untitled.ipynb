# %%
import pandas as pd
import numpy as np
import os
import openpyxl as pxl

# %%
data=pd.read_excel('2019_Data_Professional_Salary_Survey_Responses.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-08568a401f15> in <module>
# ----> 1 data=pd.read_excel('2019_Data_Professional_Salary_Survey_Responses.xlsx')
#
# /usr/local/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# /usr/local/lib/python3.7/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
# ...

# %%
pd.
# Out:
#                                                 0     \
# 0  (<Cell 'Salary Survey'.A1>, <Cell 'Salary Surv...
# 1                             (<Cell 'License'.A1>,)
#
#                                                 1     \
# 0  (<Cell 'Salary Survey'.A2>, <Cell 'Salary Surv...
# 1                             (<Cell 'License'.A2>,)
#
#                                                 2     \
# 0  (<Cell 'Salary Survey'.A3>, <Cell 'Salary Surv...
# 1                             (<Cell 'License'.A3>,)
#
#                                                 3     \
# 0  (<Cell 'Salary Survey'.A4>, <Cell 'Salary Surv...
# 1                             (<Cell 'License'.A4>,)
#
#                                                 4     \
# 0  (<Cell 'Salary Survey'.A5>, <Cell 'Salary Surv...
# 1                             (<Cell 'License'.A5>,)
#
#                                                 5     \
# 0  (<Cell 'Salary Survey'.A6>, <Cell 'Salary Surv...
# ...

# %%
a=pxl.load_workbook('2019_Data_Professional_Salary_Survey_Responses.xlsx')
a_sheet=a['Salary Survey']
itrtr=a_sheet.values
for i in range(4):
    headers=next(itrtr)
df=pd.DataFrame(itrtr, columns=headers)

# %%
df.columns
# Out:
# Index(['Survey Year', 'Timestamp', 'SalaryUSD', 'Country', 'PostalCode',
#        'PrimaryDatabase', 'YearsWithThisDatabase', 'OtherDatabases',
#        'EmploymentStatus', 'JobTitle', 'ManageStaff', 'YearsWithThisTypeOfJob',
#        'HowManyCompanies', 'OtherPeopleOnYourTeam', 'CompanyEmployeesOverall',
#        'DatabaseServers', 'Education', 'EducationIsComputerRelated',
#        'Certifications', 'HoursWorkedPerWeek', 'TelecommuteDaysPerWeek',
#        'PopulationOfLargestCityWithin20Miles', 'EmploymentSector',
#        'LookingForAnotherJob', 'CareerPlansThisYear', 'Gender',
#        'OtherJobDuties', 'KindsOfTasksPerformed', 'Counter'],
#       dtype='object')

# %%
df['JobTitle'].unique()
# Out:
# array(['DBA', 'Other', 'Developer: App code (C#, JS, etc)', 'Engineer',
#        'Developer: T-SQL',
#        'Developer: Business Intelligence (SSRS, PowerBI, etc)',
#        'Architect', 'Analyst', 'Manager', 'Data Scientist',
#        'Principal database engineer', 'DevOps, Sr Software Engineer DBA',
#        'Technician ', 'Database Specialist', 'Consultant',
#        'Systems Administrator', 'Sales', 'DBA / BI Developer',
#        'Sr Consultant ', 'Analytics consultant',
#        'DBA (General - splits time evenly between writing & tuning queries AND building & troubleshooting servers)',
#        'DBA (Development Focus - tunes queries, indexes, does deployments)',
#        'DBA (Production Focus - build & troubleshoot servers, HA/DR)'],
#       dtype=object)

# %%
df_new=pd.read_excel('state_M2019_dl.xlsx')

# %%
df_new.head()
# Out:
#    area area_title  area_type  naics     naics_title         i_group  \
# 0     1    Alabama          2      0  Cross-industry  cross-industry
# 1     1    Alabama          2      0  Cross-industry  cross-industry
# 2     1    Alabama          2      0  Cross-industry  cross-industry
# 3     1    Alabama          2      0  Cross-industry  cross-industry
# 4     1    Alabama          2      0  Cross-industry  cross-industry
#
#    own_code occ_code                        occ_title   o_group  ... h_median  \
# 0      1235  00-0000                  All Occupations     total  ...    16.73
# 1      1235  11-0000           Management Occupations     major  ...    45.03
# 2      1235  11-1011                 Chief Executives  detailed  ...    86.91
# 3      1235  11-1021  General and Operations Managers  detailed  ...    47.42
# 4      1235  11-1031                      Legislators  detailed  ...        *
#
#   h_pct75 h_pct90 a_pct10  a_pct25 a_median a_pct75 a_pct90 annual hourly
# ...

# %%
df_new['loc_quotient'].head()
# Out:
# 0       1
# 1    0.77
# 2    0.48
# 3    0.95
# 4    1.58
# Name: loc_quotient, dtype: object

# %%
# Out:
# array([nan, True], dtype=object)
